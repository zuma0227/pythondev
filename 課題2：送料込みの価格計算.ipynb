# %%
text = int(input("税抜き価格を入力してください"))
yen = round(text * 1.1)

if yen >= 2000:
    print("「送料は無料です」")
    print(f"「送料込みの金額は{yen:,}です。」")
    
else:
    print("「送料として350円かかります」")
    print(f"「送料込みの金額は{yen + 350:,}円です。」") #カンマを入れてみました。
# Out:
# 「送料は無料です」
# 「送料込みの金額は2,200です。」
