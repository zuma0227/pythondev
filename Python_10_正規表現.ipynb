# %% [markdown]
# ## 正規表現の簡単な使い方

# %% [markdown]
# ### 検索用データのダウンロード

# %%
with open("./dummy_txt/dummy.txt", encoding="utf-8") as f:
    text = f.read()

print(text)
# Out:
# 名前,ふりがな,メールアドレス,性別,年齢,誕生日,血液型,都道府県,電話番号
# 土橋 美幸,つちはし みゆき,tsuchihashi_miyuki@example.com,女,27,1992/12/25,O型,千葉県,046-863-1184
# 斎藤 綾女,さいとう あやめ,saitou_ayame@example.com,女,39,1981/8/8,B型,茨城県,022-741-5722
# 宮沢 愛子,みやざわ あいこ,miyazawa_aiko@example.com,女,57,1962/11/12,A型,三重県,031-630-9402
# 外山 亮,そとやま りょう,sotoyama_ryou@example.com,男,38,1982/6/4,AB型,北海道,093-790-9904
# 村松 照生,むらまつ てるお,muramatsu_teruo@example.com,男,36,1984/6/6,A型,高知県,052-207-6595
# 近藤 剛基,こんどう よしき,kondou_yoshiki@example.com,男,71,1948/9/27,O型,兵庫県,083-462-5184
# 西本 そら,にしもと そら,nishimoto_sora@example.com,女,25,1995/5/8,A型,岐阜県,099-112-5418
# 浅田 染五郎,あさだ そめごろう,asada_somegorou@example.com,男,33,1987/8/5,O型,東京都,091-686-6226
# 安永 花,やすなが はな,yasunaga_hana@example.com,女,67,1952/9/10,A型,岩手県,016-573-6314
# 矢田 洋,やだ よう,yada_you@example.com,男,71,1949/7/4,A型,鹿児島県,092-370-1148
# 小松 法嗣,こまつ ほうし,komatsu_houshi@example.com,男,50,1970/4/4,A型,新潟県,085-936-5065
# 仲田 明宏,なかた あきひろ,nakata_akihiro@example.com,男,66,1953/9/10,O型,東京都,055-435-1392
# 佐古 美智子,さこ みちこ,sako_michiko@example.com,女,27,1993/7/5,B型,東京都,082-743-2948
# 遠藤 憲史,えんどう のりひと,enndou_norihito@example.com,男,25,1994/11/16,AB型,熊本県,036-711-7714
# 西井 きみまろ,にしい きみまろ,nishii_kimimaro@example.com,男,80,1939/9/14,B型,大阪府,083-556-4164
# 村山 有海,むらやま あみ,murayama_ami@example.com,女,21,1998/11/10,AB型,神奈川県,064-625-9792
# 岩村 慢太郎,いわむら まんたろう,iwamura_mantarou@example.com,男,45,1975/4/23,O型,東京都,025-143-2582
# 福原 美月,ふくはら みづき,fukuhara_miduki@example.com,女,72,1947/9/5,A型,東京都,053-779-1632
# 平沢 はるみ,ひらさわ はるみ,hirasawa_harumi@example.com,女,66,1954/6/3,B型,大阪府,035-623-5976
# 海野 七世,うみの ななせ,umino_nanase@example.com,女,31,1988/11/21,O型,高知県,071-977-8336
# 寺島 誠治,てらしま せいじ,terashima_seiji@example.com,男,46,1974/4/14,O型,大阪府,097-823-1758
# 相原 菜摘,あいはら なつみ,aihara_natsumi@example.com,女,50,1969/9/5,A型,大阪府,028-944-7462
# 向井 夏希,むらい なつき,murai_natsuki@example.com,女,76,1944/3/2,B型,和歌山県,023-148-9390
# 妻夫木 恵望子,つまぶき えみこ,tsumabuki_emiko@example.com,女,74,1945/11/27,O型,茨城県,022-453-6326
# 三宅 竜也,みやけ たつや,miyake_tatsuya@example.com,男,56,1964/6/28,O型,富山県,084-393-3713
# 水上 璃子,みずかみ りこ,mizukami_riko@example.com,女,45,1975/3/28,A型,島根県,086-934-6224
# 内海 朝香,うちみ あさか,uchimi_asaka@example.com,女,50,1970/6/10,O型,京都府,074-804-5288
# 長崎 コウ,ながさき こう,nagasaki_kou@example.com,女,20,2000/3/23,B型,愛知県,093-228-4935
# 細川 憲一,ほそかわ けんいち,hosokawa_kenichi@example.com,男,31,1988/11/27,B型,岩手県,033-870-2873
# 永田 涼子,ながた りょうこ,nagata_ryouko@example.com,女,57,1962/10/8,B型,大阪府,093-956-2244
# 堤 杏,つつみ あん,tsutsumi_ann@example.com,女,44,1976/5/20,A型,滋賀県,036-941-3494
# 阪口 美和子,さかぐち みわこ,sakaguchi_miwako@example.com,女,58,1962/5/28,A型,大阪府,072-998-1783
# 芦田 徹,あしだ とおる,ashida_tohru@example.com,男,79,1941/5/6,B型,広島県,097-951-2710
# 坂井 倫子,さかい のりこ,sakai_noriko@example.com,女,61,1959/1/23,A型,茨城県,029-306-8966
# 菅野 由美子,かんの ゆみこ,kanno_yumiko@example.com,女,44,1975/11/9,O型,広島県,083-665-8117
# 甲斐 小雁,かい こがん,kai_kogan@example.com,男,25,1995/2/23,A型,福岡県,099-898-4169
# 小野田 仁,おのだ じん,onoda_jin@example.com,男,64,1956/5/26,B型,千葉県,037-201-8776
# 栗原 沙知絵,くりはら さちえ,kurihara_sachie@example.com,女,57,1963/4/14,A型,広島県,018-993-5863
# 荒井 サダヲ,あらい さだお,arai_sadawo@example.com,男,76,1944/7/23,A型,千葉県,054-747-3847
# 丸山 那奈,まるやま なな,maruyama_nana@example.com,女,42,1978/8/12,O型,佐賀県,098-493-7377
# 古田 妃里,ふるた ゆり,furuta_yuri@example.com,女,61,1958/11/29,O型,愛知県,070-798-9580
# 田村 草太,たむら そうた,tamura_souta@example.com,男,72,1948/3/16,A型,新潟県,078-399-6634
# 渡部 誠一,わたべ せいいち,watabe_seiichi@example.com,男,56,1964/6/28,B型,岐阜県,055-956-9760
# 小池 優,こいけ ゆう,koike_yuu@example.com,女,21,1998/12/15,AB型,秋田県,090-713-7714
# 神保 彩,じんぼ あや,jinbo_aya@example.com,女,32,1988/7/15,B型,神奈川県,077-913-8560
# 神原 惇,かんばら じゅん,kannbara_jun@example.com,男,58,1962/6/12,B型,新潟県,045-455-6687
# 邑野 幸子,むらの さちこ,murano_sachiko@example.com,女,28,1991/10/30,A型,神奈川県,071-315-9797

# %% [markdown]
# ### 「任意の1文字（この1文字は何でも良い）」という指定

# %%
import re
re.findall(r".", text)
# Out:
# ['名',
#  '前',
#  ',',
#  'ふ',
#  'り',
#  'が',
#  'な',
#  ',',
#  'メ',
#  'ー',
#  'ル',
#  'ア',
#  'ド',
#  'レ',
#  'ス',
#  ',',
#  '性',
#  '別',
#  ',',
#  '年',
#  '齢',
#  ',',
#  '誕',
#  '生',
#  '日',
#  ',',
#  '血',
#  '液',
#  '型',
#  ',',
#  '都',
#  '道',
#  '府',
#  '県',
#  ',',
#  '電',
#  '話',
#  '番',
#  '号',
#  '土',
#  '橋',
#  ' ',
#  '美',
#  '幸',
#  ',',
#  'つ',
#  'ち',
#  'は',
#  'し',
#  ' ',
#  'み',
#  'ゆ',
#  'き',
#  ',',
#  't',
#  's',
#  'u',
#  'c',
#  'h',
#  'i',
#  'h',
#  'a',
#  's',
#  'h',
#  'i',
#  '_',
#  'm',
#  'i',
#  'y',
#  'u',
#  'k',
#  'i',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '女',
#  ',',
#  '2',
#  '7',
#  ',',
#  '1',
#  '9',
#  '9',
#  '2',
#  '/',
#  '1',
#  '2',
#  '/',
#  '2',
#  '5',
#  ',',
#  'O',
#  '型',
#  ',',
#  '千',
#  '葉',
#  '県',
#  ',',
#  '0',
#  '4',
#  '6',
#  '-',
#  '8',
#  '6',
#  '3',
#  '-',
#  '1',
#  '1',
#  '8',
#  '4',
#  '斎',
#  '藤',
#  ' ',
#  '綾',
#  '女',
#  ',',
#  'さ',
#  'い',
#  'と',
#  'う',
#  ' ',
#  'あ',
#  'や',
#  'め',
#  ',',
#  's',
#  'a',
#  'i',
#  't',
#  'o',
#  'u',
#  '_',
#  'a',
#  'y',
#  'a',
#  'm',
#  'e',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '女',
#  ',',
#  '3',
#  '9',
#  ',',
#  '1',
#  '9',
#  '8',
#  '1',
#  '/',
#  '8',
#  '/',
#  '8',
#  ',',
#  'B',
#  '型',
#  ',',
#  '茨',
#  '城',
#  '県',
#  ',',
#  '0',
#  '2',
#  '2',
#  '-',
#  '7',
#  '4',
#  '1',
#  '-',
#  '5',
#  '7',
#  '2',
#  '2',
#  '宮',
#  '沢',
#  ' ',
#  '愛',
#  '子',
#  ',',
#  'み',
#  'や',
#  'ざ',
#  'わ',
#  ' ',
#  'あ',
#  'い',
#  'こ',
#  ',',
#  'm',
#  'i',
#  'y',
#  'a',
#  'z',
#  'a',
#  'w',
#  'a',
#  '_',
#  'a',
#  'i',
#  'k',
#  'o',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '女',
#  ',',
#  '5',
#  '7',
#  ',',
#  '1',
#  '9',
#  '6',
#  '2',
#  '/',
#  '1',
#  '1',
#  '/',
#  '1',
#  '2',
#  ',',
#  'A',
#  '型',
#  ',',
#  '三',
#  '重',
#  '県',
#  ',',
#  '0',
#  '3',
#  '1',
#  '-',
#  '6',
#  '3',
#  '0',
#  '-',
#  '9',
#  '4',
#  '0',
#  '2',
#  '外',
#  '山',
#  ' ',
#  '亮',
#  ',',
#  'そ',
#  'と',
#  'や',
#  'ま',
#  ' ',
#  'り',
#  'ょ',
#  'う',
#  ',',
#  's',
#  'o',
#  't',
#  'o',
#  'y',
#  'a',
#  'm',
#  'a',
#  '_',
#  'r',
#  'y',
#  'o',
#  'u',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '3',
#  '8',
#  ',',
#  '1',
#  '9',
#  '8',
#  '2',
#  '/',
#  '6',
#  '/',
#  '4',
#  ',',
#  'A',
#  'B',
#  '型',
#  ',',
#  '北',
#  '海',
#  '道',
#  ',',
#  '0',
#  '9',
#  '3',
#  '-',
#  '7',
#  '9',
#  '0',
#  '-',
#  '9',
#  '9',
#  '0',
#  '4',
#  '村',
#  '松',
#  ' ',
#  '照',
#  '生',
#  ',',
#  'む',
#  'ら',
#  'ま',
#  'つ',
#  ' ',
#  'て',
#  'る',
#  'お',
#  ',',
#  'm',
#  'u',
#  'r',
#  'a',
#  'm',
#  'a',
#  't',
#  's',
#  'u',
#  '_',
#  't',
#  'e',
#  'r',
#  'u',
#  'o',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '3',
#  '6',
#  ',',
#  '1',
#  '9',
#  '8',
#  '4',
#  '/',
#  '6',
#  '/',
#  '6',
#  ',',
#  'A',
#  '型',
#  ',',
#  '高',
#  '知',
#  '県',
#  ',',
#  '0',
#  '5',
#  '2',
#  '-',
#  '2',
#  '0',
#  '7',
#  '-',
#  '6',
#  '5',
#  '9',
#  '5',
#  '近',
#  '藤',
#  ' ',
#  '剛',
#  '基',
#  ',',
#  'こ',
#  'ん',
#  'ど',
#  'う',
#  ' ',
#  'よ',
#  'し',
#  'き',
#  ',',
#  'k',
#  'o',
#  'n',
#  'd',
#  'o',
#  'u',
#  '_',
#  'y',
#  'o',
#  's',
#  'h',
#  'i',
#  'k',
#  'i',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '7',
#  '1',
#  ',',
#  '1',
#  '9',
#  '4',
#  '8',
#  '/',
#  '9',
#  '/',
#  '2',
#  '7',
#  ',',
#  'O',
#  '型',
#  ',',
#  '兵',
#  '庫',
#  '県',
#  ',',
#  '0',
#  '8',
#  '3',
#  '-',
#  '4',
#  '6',
#  '2',
#  '-',
#  '5',
#  '1',
#  '8',
#  '4',
#  '西',
#  '本',
#  ' ',
#  'そ',
#  'ら',
#  ',',
#  'に',
#  'し',
#  'も',
#  'と',
#  ' ',
#  'そ',
#  'ら',
#  ',',
#  'n',
#  'i',
#  's',
#  'h',
#  'i',
#  'm',
#  'o',
#  't',
#  'o',
#  '_',
#  's',
#  'o',
#  'r',
#  'a',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '女',
#  ',',
#  '2',
#  '5',
#  ',',
#  '1',
#  '9',
#  '9',
#  '5',
#  '/',
#  '5',
#  '/',
#  '8',
#  ',',
#  'A',
#  '型',
#  ',',
#  '岐',
#  '阜',
#  '県',
#  ',',
#  '0',
#  '9',
#  '9',
#  '-',
#  '1',
#  '1',
#  '2',
#  '-',
#  '5',
#  '4',
#  '1',
#  '8',
#  '浅',
#  '田',
#  ' ',
#  '染',
#  '五',
#  '郎',
#  ',',
#  'あ',
#  'さ',
#  'だ',
#  ' ',
#  'そ',
#  'め',
#  'ご',
#  'ろ',
#  'う',
#  ',',
#  'a',
#  's',
#  'a',
#  'd',
#  'a',
#  '_',
#  's',
#  'o',
#  'm',
#  'e',
#  'g',
#  'o',
#  'r',
#  'o',
#  'u',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '3',
#  '3',
#  ',',
#  '1',
#  '9',
#  '8',
#  '7',
#  '/',
#  '8',
#  '/',
#  '5',
#  ',',
#  'O',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '0',
#  '9',
#  '1',
#  '-',
#  '6',
#  '8',
#  '6',
#  '-',
#  '6',
#  '2',
#  '2',
#  '6',
#  '安',
#  '永',
#  ' ',
#  '花',
#  ',',
#  'や',
#  'す',
#  'な',
#  'が',
#  ' ',
#  'は',
#  'な',
#  ',',
#  'y',
#  'a',
#  's',
#  'u',
#  'n',
#  'a',
#  'g',
#  'a',
#  '_',
#  'h',
#  'a',
#  'n',
#  'a',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '女',
#  ',',
#  '6',
#  '7',
#  ',',
#  '1',
#  '9',
#  '5',
#  '2',
#  '/',
#  '9',
#  '/',
#  '1',
#  '0',
#  ',',
#  'A',
#  '型',
#  ',',
#  '岩',
#  '手',
#  '県',
#  ',',
#  '0',
#  '1',
#  '6',
#  '-',
#  '5',
#  '7',
#  '3',
#  '-',
#  '6',
#  '3',
#  '1',
#  '4',
#  '矢',
#  '田',
#  ' ',
#  '洋',
#  ',',
#  'や',
#  'だ',
#  ' ',
#  'よ',
#  'う',
#  ',',
#  'y',
#  'a',
#  'd',
#  'a',
#  '_',
#  'y',
#  'o',
#  'u',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '7',
#  '1',
#  ',',
#  '1',
#  '9',
#  '4',
#  '9',
#  '/',
#  '7',
#  '/',
#  '4',
#  ',',
#  'A',
#  '型',
#  ',',
#  '鹿',
#  '児',
#  '島',
#  '県',
#  ',',
#  '0',
#  '9',
#  '2',
#  '-',
#  '3',
#  '7',
#  '0',
#  '-',
#  '1',
#  '1',
#  '4',
#  '8',
#  '小',
#  '松',
#  ' ',
#  '法',
#  '嗣',
#  ',',
#  'こ',
#  'ま',
#  'つ',
#  ' ',
#  'ほ',
#  'う',
#  'し',
#  ',',
#  'k',
#  'o',
#  'm',
#  'a',
#  't',
#  's',
#  'u',
#  '_',
#  'h',
#  'o',
#  'u',
#  's',
#  'h',
#  'i',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '5',
#  '0',
#  ',',
#  '1',
#  '9',
#  '7',
#  '0',
#  '/',
#  '4',
#  '/',
#  '4',
#  ',',
#  'A',
#  '型',
#  ',',
#  '新',
#  '潟',
#  '県',
#  ',',
#  '0',
#  '8',
#  '5',
#  '-',
#  '9',
#  '3',
#  '6',
#  '-',
#  '5',
#  '0',
#  '6',
#  '5',
#  '仲',
#  '田',
#  ' ',
#  '明',
#  '宏',
#  ',',
#  'な',
#  'か',
#  'た',
#  ' ',
#  'あ',
#  'き',
#  'ひ',
#  'ろ',
#  ',',
#  'n',
#  'a',
#  'k',
#  'a',
#  't',
#  'a',
#  '_',
#  'a',
#  'k',
#  'i',
#  'h',
#  'i',
#  'r',
#  'o',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '男',
#  ',',
#  '6',
#  '6',
#  ',',
#  '1',
#  '9',
#  '5',
#  '3',
#  '/',
#  '9',
#  '/',
#  '1',
#  '0',
#  ',',
#  'O',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '0',
#  '5',
#  '5',
#  '-',
#  '4',
#  '3',
#  '5',
#  '-',
#  '1',
#  '3',
#  '9',
#  '2',
#  '佐',
#  '古',
#  ' ',
#  '美',
#  '智',
#  '子',
#  ',',
#  'さ',
#  'こ',
#  ' ',
#  'み',
#  'ち',
#  'こ',
#  ',',
#  's',
#  'a',
#  'k',
#  'o',
#  '_',
#  'm',
#  'i',
#  'c',
#  'h',
#  'i',
#  'k',
#  'o',
#  '@',
#  'e',
#  'x',
#  'a',
#  'm',
#  'p',
#  'l',
#  'e',
#  '.',
#  'c',
#  'o',
#  'm',
#  ',',
#  '女',
#  ',',
#  '2',
#  '7',
#  ',',
#  '1',
#  '9',
#  '9',
#  '3',
#  '/',
#  '7',
#  '/',
#  '5',
#  ',',
#  'B',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '0',
#  '8',
#  '2',
#  '-',
#  ...]

# %%
re.findall(r"山.県", text)
# Out:
# ['山口県', '山形県', '山梨県']

# %% [markdown]
# ### ドットは連続で入力可能

# %%
re.findall(r"和..県", text)
# Out:
# ['和歌山県']

# %% [markdown]
# ### 「行頭と行末にある文字」という指定

# %% [markdown]
# #### 行頭の場合

# %%
re.findall(r"福.", text)
# Out:
# ['福原', '福井', '福岡', '福島', '福岡', '福岡', '福井', '福岡']

# %%
re.findall(r"^福.", text, re.MULTILINE)
# Out:
# ['福原']

# %% [markdown]
# #### 行末の場合

# %%
re.findall(r"5976$", text, re.MULTILINE)
# Out:
# ['5976']

# %% [markdown]
# ### 「任意の○文字」という指定

# %% [markdown]
# #### 文字数が固定の場合

# %%
re.findall(r"和.{2}県", text, re.MULTILINE)
# Out:
# ['和歌山県']

# %% [markdown]
# #### 文字数が不定の場合

# %%
re.findall(r"^北.? .{2}", text, re.MULTILINE)
# Out:
# ['北 信彦', '北中 そら']

# %% [markdown]
# ### 「この1文字が指定した文字のどれか」という指定

# %%
re.findall(r"[0-9]{3}-[0-9]{3}-[0-9]{4}", text)
# Out:
# ['046-863-1184',
#  '022-741-5722',
#  '031-630-9402',
#  '093-790-9904',
#  '052-207-6595',
#  '083-462-5184',
#  '099-112-5418',
#  '091-686-6226',
#  '016-573-6314',
#  '092-370-1148',
#  '085-936-5065',
#  '055-435-1392',
#  '082-743-2948',
#  '036-711-7714',
#  '083-556-4164',
#  '064-625-9792',
#  '025-143-2582',
#  '053-779-1632',
#  '035-623-5976',
#  '071-977-8336',
#  '097-823-1758',
#  '028-944-7462',
#  '023-148-9390',
#  '022-453-6326',
#  '061-746-3664',
#  '099-314-6781',
#  '029-710-2090',
#  '066-347-6519',
#  '087-189-2817',
#  '069-294-4436',
#  '096-990-5535',
#  '060-854-6427',
#  '033-842-2376',
#  '017-940-4802',
#  '028-365-4211',
#  '078-769-1845',
#  '031-980-7143',
#  '093-362-7464',
#  '096-694-6334',
#  '091-327-5123',
#  '057-924-8301',
#  '093-639-4835',
#  '018-751-6917',
#  '062-134-8798',
#  '095-856-2951',
#  '091-839-3809',
#  '088-996-6947',
#  '041-267-5841',
#  '052-987-2639',
#  '011-679-9758',
#  '012-858-4317',
#  '024-790-9989',
#  '097-940-9217',
#  '038-768-3894',
#  '066-925-3072',
#  '018-871-2413',
#  '057-245-3613',
#  '096-997-4363',
#  '036-654-7575',
#  '064-468-9303',
#  '097-757-8381',
#  '081-479-7266',
#  '037-796-7245',
#  '095-103-8861',
#  '096-887-8246',
#  '013-945-6269',
#  '059-180-5659',
#  '072-526-5646',
#  '014-560-4282',
#  '091-703-8433',
#  '051-706-5021',
#  '082-251-7242',
#  '049-894-8836',
#  '097-124-9467',
#  '095-403-3246',
#  '019-744-2818',
#  '047-724-9867',
#  '084-393-3713',
#  '086-934-6224',
#  '074-804-5288',
#  '093-228-4935',
#  '033-870-2873',
#  '093-956-2244',
#  '036-941-3494',
#  '072-998-1783',
#  '097-951-2710',
#  '029-306-8966',
#  '083-665-8117',
#  '099-898-4169',
#  '037-201-8776',
#  '018-993-5863',
#  '054-747-3847',
#  '098-493-7377',
#  '070-798-9580',
#  '078-399-6634',
#  '055-956-9760',
#  '090-713-7714',
#  '077-913-8560',
#  '045-455-6687',
#  '071-315-9797']

# %% [markdown]
# ### 「この1文字が指定した文字以外のどれか」という指定

# %%
re.findall(r"[^a-zA-Z0-9]", text)
# Out:
# ['名',
#  '前',
#  ',',
#  'ふ',
#  'り',
#  'が',
#  'な',
#  ',',
#  'メ',
#  'ー',
#  'ル',
#  'ア',
#  'ド',
#  'レ',
#  'ス',
#  ',',
#  '性',
#  '別',
#  ',',
#  '年',
#  '齢',
#  ',',
#  '誕',
#  '生',
#  '日',
#  ',',
#  '血',
#  '液',
#  '型',
#  ',',
#  '都',
#  '道',
#  '府',
#  '県',
#  ',',
#  '電',
#  '話',
#  '番',
#  '号',
#  '\n',
#  '土',
#  '橋',
#  ' ',
#  '美',
#  '幸',
#  ',',
#  'つ',
#  'ち',
#  'は',
#  'し',
#  ' ',
#  'み',
#  'ゆ',
#  'き',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '千',
#  '葉',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '斎',
#  '藤',
#  ' ',
#  '綾',
#  '女',
#  ',',
#  'さ',
#  'い',
#  'と',
#  'う',
#  ' ',
#  'あ',
#  'や',
#  'め',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '茨',
#  '城',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '宮',
#  '沢',
#  ' ',
#  '愛',
#  '子',
#  ',',
#  'み',
#  'や',
#  'ざ',
#  'わ',
#  ' ',
#  'あ',
#  'い',
#  'こ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '三',
#  '重',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '外',
#  '山',
#  ' ',
#  '亮',
#  ',',
#  'そ',
#  'と',
#  'や',
#  'ま',
#  ' ',
#  'り',
#  'ょ',
#  'う',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '北',
#  '海',
#  '道',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '村',
#  '松',
#  ' ',
#  '照',
#  '生',
#  ',',
#  'む',
#  'ら',
#  'ま',
#  'つ',
#  ' ',
#  'て',
#  'る',
#  'お',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '高',
#  '知',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '近',
#  '藤',
#  ' ',
#  '剛',
#  '基',
#  ',',
#  'こ',
#  'ん',
#  'ど',
#  'う',
#  ' ',
#  'よ',
#  'し',
#  'き',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '兵',
#  '庫',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '西',
#  '本',
#  ' ',
#  'そ',
#  'ら',
#  ',',
#  'に',
#  'し',
#  'も',
#  'と',
#  ' ',
#  'そ',
#  'ら',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '岐',
#  '阜',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '浅',
#  '田',
#  ' ',
#  '染',
#  '五',
#  '郎',
#  ',',
#  'あ',
#  'さ',
#  'だ',
#  ' ',
#  'そ',
#  'め',
#  'ご',
#  'ろ',
#  'う',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '安',
#  '永',
#  ' ',
#  '花',
#  ',',
#  'や',
#  'す',
#  'な',
#  'が',
#  ' ',
#  'は',
#  'な',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '岩',
#  '手',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '矢',
#  '田',
#  ' ',
#  '洋',
#  ',',
#  'や',
#  'だ',
#  ' ',
#  'よ',
#  'う',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '鹿',
#  '児',
#  '島',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '小',
#  '松',
#  ' ',
#  '法',
#  '嗣',
#  ',',
#  'こ',
#  'ま',
#  'つ',
#  ' ',
#  'ほ',
#  'う',
#  'し',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '新',
#  '潟',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '仲',
#  '田',
#  ' ',
#  '明',
#  '宏',
#  ',',
#  'な',
#  'か',
#  'た',
#  ' ',
#  'あ',
#  'き',
#  'ひ',
#  'ろ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '佐',
#  '古',
#  ' ',
#  '美',
#  '智',
#  '子',
#  ',',
#  'さ',
#  'こ',
#  ' ',
#  'み',
#  'ち',
#  'こ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '遠',
#  '藤',
#  ' ',
#  '憲',
#  '史',
#  ',',
#  'え',
#  'ん',
#  'ど',
#  'う',
#  ' ',
#  'の',
#  'り',
#  'ひ',
#  'と',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '熊',
#  '本',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '西',
#  '井',
#  ' ',
#  'き',
#  'み',
#  'ま',
#  'ろ',
#  ',',
#  'に',
#  'し',
#  'い',
#  ' ',
#  'き',
#  'み',
#  'ま',
#  'ろ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '大',
#  '阪',
#  '府',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '村',
#  '山',
#  ' ',
#  '有',
#  '海',
#  ',',
#  'む',
#  'ら',
#  'や',
#  'ま',
#  ' ',
#  'あ',
#  'み',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '神',
#  '奈',
#  '川',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '岩',
#  '村',
#  ' ',
#  '慢',
#  '太',
#  '郎',
#  ',',
#  'い',
#  'わ',
#  'む',
#  'ら',
#  ' ',
#  'ま',
#  'ん',
#  'た',
#  'ろ',
#  'う',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '福',
#  '原',
#  ' ',
#  '美',
#  '月',
#  ',',
#  'ふ',
#  'く',
#  'は',
#  'ら',
#  ' ',
#  'み',
#  'づ',
#  'き',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '東',
#  '京',
#  '都',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '平',
#  '沢',
#  ' ',
#  'は',
#  'る',
#  'み',
#  ',',
#  'ひ',
#  'ら',
#  'さ',
#  'わ',
#  ' ',
#  'は',
#  'る',
#  'み',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '大',
#  '阪',
#  '府',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '海',
#  '野',
#  ' ',
#  '七',
#  '世',
#  ',',
#  'う',
#  'み',
#  'の',
#  ' ',
#  'な',
#  'な',
#  'せ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '高',
#  '知',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '寺',
#  '島',
#  ' ',
#  '誠',
#  '治',
#  ',',
#  'て',
#  'ら',
#  'し',
#  'ま',
#  ' ',
#  'せ',
#  'い',
#  'じ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '大',
#  '阪',
#  '府',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '相',
#  '原',
#  ' ',
#  '菜',
#  '摘',
#  ',',
#  'あ',
#  'い',
#  'は',
#  'ら',
#  ' ',
#  'な',
#  'つ',
#  'み',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '大',
#  '阪',
#  '府',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '向',
#  '井',
#  ' ',
#  '夏',
#  '希',
#  ',',
#  'む',
#  'ら',
#  'い',
#  ' ',
#  'な',
#  'つ',
#  'き',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '和',
#  '歌',
#  '山',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '妻',
#  '夫',
#  '木',
#  ' ',
#  '恵',
#  '望',
#  '子',
#  ',',
#  'つ',
#  'ま',
#  'ぶ',
#  'き',
#  ' ',
#  'え',
#  'み',
#  'こ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '茨',
#  '城',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '石',
#  '垣',
#  ' ',
#  'え',
#  'み',
#  ',',
#  'い',
#  'し',
#  'が',
#  'き',
#  ' ',
#  'え',
#  'み',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '山',
#  '口',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '玉',
#  '山',
#  ' ',
#  '砂',
#  '羽',
#  ',',
#  'た',
#  'ま',
#  'や',
#  'ま',
#  ' ',
#  'さ',
#  'わ',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '香',
#  '川',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '豊',
#  '田',
#  ' ',
#  '秀',
#  '樹',
#  ',',
#  'と',
#  'よ',
#  'た',
#  ' ',
#  'ひ',
#  'で',
#  'き',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '男',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '愛',
#  '知',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '唐',
#  '沢',
#  ' ',
#  'ま',
#  'さ',
#  'み',
#  ',',
#  'か',
#  'ら',
#  'さ',
#  'わ',
#  ' ',
#  'ま',
#  'さ',
#  'み',
#  ',',
#  '_',
#  '@',
#  '.',
#  ',',
#  '女',
#  ',',
#  ',',
#  '/',
#  '/',
#  ',',
#  '型',
#  ',',
#  '大',
#  '分',
#  '県',
#  ',',
#  '-',
#  '-',
#  '\n',
#  '高',
#  '岡',
#  ' ',
#  '早',
#  '織',
#  ',',
#  'た',
#  'か',
#  'お',
#  ...]

# %% [markdown]
# ### 「指定した単語のどれか」という指定

# %%
re.findall(r"(埼玉|新潟|香川)県", text, re.MULTILINE)
# Out:
# ['新潟', '香川', '埼玉', '埼玉', '新潟', '埼玉', '新潟', '新潟', '新潟']

# %% [markdown]
# ## 正規表現の応用

# %% [markdown]
# ### 複数のメタキャラクタの利用

# %%
dates = """\
昭和53年10月31日
平成10年06月10日
令和02年01月21日
2020年07月24日
令和元年05月03日
2019年4月1日
'19年09月14日
"""

# %%
re.findall(r"..\d\d年\d\d月\d\d日", dates)
# Out:
# ['昭和53年10月31日', '平成10年06月10日', '令和02年01月21日', '2020年07月24日']

# %% [markdown]
# ### 任意の長さの文字列を表現

# %%
re.findall(r".+\d*年\d+月\d+日", dates)
# Out:
# ['昭和53年10月31日',
#  '平成10年06月10日',
#  '令和02年01月21日',
#  '2020年07月24日',
#  '令和元年05月03日',
#  '2019年4月1日',
#  "'19年09月14日"]

# %% [markdown]
# ### 固定の長さの文字列を表現

# %%
re.findall(r"\d{4}年\d{1,2}月\d{1,2}日", dates)
# Out:
# ['2020年07月24日', '2019年4月1日']

# %% [markdown]
# ### 先読み／後読み

# %% [markdown]
# #### 先読み（肯定先読み）

# %%
re.findall(r"山(?=形)", text)
# Out:
# ['山']

# %% [markdown]
# #### 否定先読み

# %%
re.findall(r"山(?!形)", text)
# Out:
# ['山', '山', '山', '山', '山', '山', '山', '山', '山', '山', '山']

# %% [markdown]
# #### 後読み（肯定後読み）

# %%
re.findall(r"(?<=東)京都", text)
# Out:
# ['京都', '京都', '京都', '京都', '京都', '京都', '京都', '京都', '京都', '京都']

# %% [markdown]
# #### 否定後読み

# %%
re.findall(r"(?<!東)京都", text)
# Out:
# ['京都']

# %% [markdown]
# #### 先読み／後読みの使いどころ

# %%
re.findall(r"福(?=岡)", text)
# Out:
# ['福', '福', '福', '福']

# %%
text_replaced = re.sub(r"福(?=岡)", r"静", text)
print(text_replaced)
# Out:
# 名前,ふりがな,メールアドレス,性別,年齢,誕生日,血液型,都道府県,電話番号
# 土橋 美幸,つちはし みゆき,tsuchihashi_miyuki@example.com,女,27,1992/12/25,O型,千葉県,046-863-1184
# 斎藤 綾女,さいとう あやめ,saitou_ayame@example.com,女,39,1981/8/8,B型,茨城県,022-741-5722
# 宮沢 愛子,みやざわ あいこ,miyazawa_aiko@example.com,女,57,1962/11/12,A型,三重県,031-630-9402
# 外山 亮,そとやま りょう,sotoyama_ryou@example.com,男,38,1982/6/4,AB型,北海道,093-790-9904
# 村松 照生,むらまつ てるお,muramatsu_teruo@example.com,男,36,1984/6/6,A型,高知県,052-207-6595
# 近藤 剛基,こんどう よしき,kondou_yoshiki@example.com,男,71,1948/9/27,O型,兵庫県,083-462-5184
# 西本 そら,にしもと そら,nishimoto_sora@example.com,女,25,1995/5/8,A型,岐阜県,099-112-5418
# 浅田 染五郎,あさだ そめごろう,asada_somegorou@example.com,男,33,1987/8/5,O型,東京都,091-686-6226
# 安永 花,やすなが はな,yasunaga_hana@example.com,女,67,1952/9/10,A型,岩手県,016-573-6314
# 矢田 洋,やだ よう,yada_you@example.com,男,71,1949/7/4,A型,鹿児島県,092-370-1148
# 小松 法嗣,こまつ ほうし,komatsu_houshi@example.com,男,50,1970/4/4,A型,新潟県,085-936-5065
# 仲田 明宏,なかた あきひろ,nakata_akihiro@example.com,男,66,1953/9/10,O型,東京都,055-435-1392
# 佐古 美智子,さこ みちこ,sako_michiko@example.com,女,27,1993/7/5,B型,東京都,082-743-2948
# 遠藤 憲史,えんどう のりひと,enndou_norihito@example.com,男,25,1994/11/16,AB型,熊本県,036-711-7714
# 西井 きみまろ,にしい きみまろ,nishii_kimimaro@example.com,男,80,1939/9/14,B型,大阪府,083-556-4164
# 村山 有海,むらやま あみ,murayama_ami@example.com,女,21,1998/11/10,AB型,神奈川県,064-625-9792
# 岩村 慢太郎,いわむら まんたろう,iwamura_mantarou@example.com,男,45,1975/4/23,O型,東京都,025-143-2582
# 福原 美月,ふくはら みづき,fukuhara_miduki@example.com,女,72,1947/9/5,A型,東京都,053-779-1632
# 平沢 はるみ,ひらさわ はるみ,hirasawa_harumi@example.com,女,66,1954/6/3,B型,大阪府,035-623-5976
# 海野 七世,うみの ななせ,umino_nanase@example.com,女,31,1988/11/21,O型,高知県,071-977-8336
# 寺島 誠治,てらしま せいじ,terashima_seiji@example.com,男,46,1974/4/14,O型,大阪府,097-823-1758
# 相原 菜摘,あいはら なつみ,aihara_natsumi@example.com,女,50,1969/9/5,A型,大阪府,028-944-7462
# 新村 さやか,にいむら さやか,niimura_sayaka@example.com,女,48,1972/6/17,B型,富山県,019-744-2818
# 北中 そら,きたなか そら,kitanaka_sora@example.com,女,43,1976/11/21,B型,千葉県,047-724-9867
# 三宅 竜也,みやけ たつや,miyake_tatsuya@example.com,男,56,1964/6/28,O型,富山県,084-393-3713
# 水上 璃子,みずかみ りこ,mizukami_riko@example.com,女,45,1975/3/28,A型,島根県,086-934-6224
# 内海 朝香,うちみ あさか,uchimi_asaka@example.com,女,50,1970/6/10,O型,京都府,074-804-5288
# 長崎 コウ,ながさき こう,nagasaki_kou@example.com,女,20,2000/3/23,B型,愛知県,093-228-4935
# 細川 憲一,ほそかわ けんいち,hosokawa_kenichi@example.com,男,31,1988/11/27,B型,岩手県,033-870-2873
# 永田 涼子,ながた りょうこ,nagata_ryouko@example.com,女,57,1962/10/8,B型,大阪府,093-956-2244
# 堤 杏,つつみ あん,tsutsumi_ann@example.com,女,44,1976/5/20,A型,滋賀県,036-941-3494
# 阪口 美和子,さかぐち みわこ,sakaguchi_miwako@example.com,女,58,1962/5/28,A型,大阪府,072-998-1783
# 芦田 徹,あしだ とおる,ashida_tohru@example.com,男,79,1941/5/6,B型,広島県,097-951-2710
# 坂井 倫子,さかい のりこ,sakai_noriko@example.com,女,61,1959/1/23,A型,茨城県,029-306-8966
# 菅野 由美子,かんの ゆみこ,kanno_yumiko@example.com,女,44,1975/11/9,O型,広島県,083-665-8117
# 甲斐 小雁,かい こがん,kai_kogan@example.com,男,25,1995/2/23,A型,静岡県,099-898-4169
# 小野田 仁,おのだ じん,onoda_jin@example.com,男,64,1956/5/26,B型,千葉県,037-201-8776
# 栗原 沙知絵,くりはら さちえ,kurihara_sachie@example.com,女,57,1963/4/14,A型,広島県,018-993-5863
# 荒井 サダヲ,あらい さだお,arai_sadawo@example.com,男,76,1944/7/23,A型,千葉県,054-747-3847
# 丸山 那奈,まるやま なな,maruyama_nana@example.com,女,42,1978/8/12,O型,佐賀県,098-493-7377
# 古田 妃里,ふるた ゆり,furuta_yuri@example.com,女,61,1958/11/29,O型,愛知県,070-798-9580
# 田村 草太,たむら そうた,tamura_souta@example.com,男,72,1948/3/16,A型,新潟県,078-399-6634
# 渡部 誠一,わたべ せいいち,watabe_seiichi@example.com,男,56,1964/6/28,B型,岐阜県,055-956-9760
# 小池 優,こいけ ゆう,koike_yuu@example.com,女,21,1998/12/15,AB型,秋田県,090-713-7714
# 神保 彩,じんぼ あや,jinbo_aya@example.com,女,32,1988/7/15,B型,神奈川県,077-913-8560
# 神原 惇,かんばら じゅん,kannbara_jun@example.com,男,58,1962/6/12,B型,新潟県,045-455-6687
# 邑野 幸子,むらの さちこ,murano_sachiko@example.com,女,28,1991/10/30,A型,神奈川県,071-315-9797

# %% [markdown]
# ### 部分置換

# %%
re.findall(r"(埼玉|新潟|香川)県", text)
# Out:
# ['新潟', '香川', '埼玉', '埼玉', '新潟', '埼玉', '新潟', '新潟', '新潟']

# %%
text_replaced = re.sub(r"(埼玉|新潟|香川)県", r"\1都", text)
print(text_replaced)
# Out:
# 名前,ふりがな,メールアドレス,性別,年齢,誕生日,血液型,都道府県,電話番号
# 土橋 美幸,つちはし みゆき,tsuchihashi_miyuki@example.com,女,27,1992/12/25,O型,千葉県,046-863-1184
# 斎藤 綾女,さいとう あやめ,saitou_ayame@example.com,女,39,1981/8/8,B型,茨城県,022-741-5722
# 宮沢 愛子,みやざわ あいこ,miyazawa_aiko@example.com,女,57,1962/11/12,A型,三重県,031-630-9402
# 外山 亮,そとやま りょう,sotoyama_ryou@example.com,男,38,1982/6/4,AB型,北海道,093-790-9904
# 村松 照生,むらまつ てるお,muramatsu_teruo@example.com,男,36,1984/6/6,A型,高知県,052-207-6595
# 近藤 剛基,こんどう よしき,kondou_yoshiki@example.com,男,71,1948/9/27,O型,兵庫県,083-462-5184
# 西本 そら,にしもと そら,nishimoto_sora@example.com,女,25,1995/5/8,A型,岐阜県,099-112-5418
# 浅田 染五郎,あさだ そめごろう,asada_somegorou@example.com,男,33,1987/8/5,O型,東京都,091-686-6226
# 安永 花,やすなが はな,yasunaga_hana@example.com,女,67,1952/9/10,A型,岩手県,016-573-6314
# 矢田 洋,やだ よう,yada_you@example.com,男,71,1949/7/4,A型,鹿児島県,092-370-1148
# 小松 法嗣,こまつ ほうし,komatsu_houshi@example.com,男,50,1970/4/4,A型,新潟都,085-936-5065
# 仲田 明宏,なかた あきひろ,nakata_akihiro@example.com,男,66,1953/9/10,O型,東京都,055-435-1392
# 佐古 美智子,さこ みちこ,sako_michiko@example.com,女,27,1993/7/5,B型,東京都,082-743-2948
# 遠藤 憲史,えんどう のりひと,enndou_norihito@example.com,男,25,1994/11/16,AB型,熊本県,036-711-7714
# 西井 きみまろ,にしい きみまろ,nishii_kimimaro@example.com,男,80,1939/9/14,B型,大阪府,083-556-4164
# 村山 有海,むらやま あみ,murayama_ami@example.com,女,21,1998/11/10,AB型,神奈川県,064-625-9792
# 岩村 慢太郎,いわむら まんたろう,iwamura_mantarou@example.com,男,45,1975/4/23,O型,東京都,025-143-2582
# 福原 美月,ふくはら みづき,fukuhara_miduki@example.com,女,72,1947/9/5,A型,東京都,053-779-1632
# 平沢 はるみ,ひらさわ はるみ,hirasawa_harumi@example.com,女,66,1954/6/3,B型,大阪府,035-623-5976
# 海野 七世,うみの ななせ,umino_nanase@example.com,女,31,1988/11/21,O型,高知県,071-977-8336
# 寺島 誠治,てらしま せいじ,terashima_seiji@example.com,男,46,1974/4/14,O型,大阪府,097-823-1758
# 相原 菜摘,あいはら なつみ,aihara_natsumi@example.com,女,50,1969/9/5,A型,大阪府,028-944-7462
# 向井 夏希,むらい なつき,murai_natsuki@example.com,女,76,1944/3/2,B型,和歌山県,023-148-9390
# 妻夫木 恵望子,つまぶき えみこ,tsumabuki_emiko@example.com,女,74,1945/11/27,O型,茨城県,022-453-6326
# 石垣 えみ,いしがき えみ,ishigaki_emi@example.com,女,50,1970/3/30,B型,山口県,061-746-3664
# 内海 朝香,うちみ あさか,uchimi_asaka@example.com,女,50,1970/6/10,O型,京都府,074-804-5288
# 長崎 コウ,ながさき こう,nagasaki_kou@example.com,女,20,2000/3/23,B型,愛知県,093-228-4935
# 細川 憲一,ほそかわ けんいち,hosokawa_kenichi@example.com,男,31,1988/11/27,B型,岩手県,033-870-2873
# 永田 涼子,ながた りょうこ,nagata_ryouko@example.com,女,57,1962/10/8,B型,大阪府,093-956-2244
# 堤 杏,つつみ あん,tsutsumi_ann@example.com,女,44,1976/5/20,A型,滋賀県,036-941-3494
# 阪口 美和子,さかぐち みわこ,sakaguchi_miwako@example.com,女,58,1962/5/28,A型,大阪府,072-998-1783
# 芦田 徹,あしだ とおる,ashida_tohru@example.com,男,79,1941/5/6,B型,広島県,097-951-2710
# 坂井 倫子,さかい のりこ,sakai_noriko@example.com,女,61,1959/1/23,A型,茨城県,029-306-8966
# 菅野 由美子,かんの ゆみこ,kanno_yumiko@example.com,女,44,1975/11/9,O型,広島県,083-665-8117
# 甲斐 小雁,かい こがん,kai_kogan@example.com,男,25,1995/2/23,A型,福岡県,099-898-4169
# 小野田 仁,おのだ じん,onoda_jin@example.com,男,64,1956/5/26,B型,千葉県,037-201-8776
# 栗原 沙知絵,くりはら さちえ,kurihara_sachie@example.com,女,57,1963/4/14,A型,広島県,018-993-5863
# 荒井 サダヲ,あらい さだお,arai_sadawo@example.com,男,76,1944/7/23,A型,千葉県,054-747-3847
# 丸山 那奈,まるやま なな,maruyama_nana@example.com,女,42,1978/8/12,O型,佐賀県,098-493-7377
# 古田 妃里,ふるた ゆり,furuta_yuri@example.com,女,61,1958/11/29,O型,愛知県,070-798-9580
# 田村 草太,たむら そうた,tamura_souta@example.com,男,72,1948/3/16,A型,新潟都,078-399-6634
# 渡部 誠一,わたべ せいいち,watabe_seiichi@example.com,男,56,1964/6/28,B型,岐阜県,055-956-9760
# 小池 優,こいけ ゆう,koike_yuu@example.com,女,21,1998/12/15,AB型,秋田県,090-713-7714
# 神保 彩,じんぼ あや,jinbo_aya@example.com,女,32,1988/7/15,B型,神奈川県,077-913-8560
# 神原 惇,かんばら じゅん,kannbara_jun@example.com,男,58,1962/6/12,B型,新潟都,045-455-6687
# 邑野 幸子,むらの さちこ,murano_sachiko@example.com,女,28,1991/10/30,A型,神奈川県,071-315-9797

# %% [markdown]
# ## 正規表現で入力値チェックを行なう

# %%
import re

rep = r'(?=.*\d)(?=.*[a-z])(?=.*[A-Z]).{8,}'
password1 = 'password'
password2 = 'pass'
password3 = 'Passw0rd'

print(f'{password1}：',end='')
if re.match(rep, password1) :
    print('パターンに合致しています。')
else:
    print('パターンに合致していません。')

print(f'{password2}：',end='')
if re.match(rep, password2) :
    print('パターンに合致しています。')
else:
    print('パターンに合致していません。')

print(f'{password3}：',end='')
if re.match(rep, password3) :
    print('パターンに合致しています。')
else:
    print('パターンに合致していません。')
# Out:
# password：パターンに合致していません。
# pass：パターンに合致していません。
# Passw0rd：パターンに合致しています。
